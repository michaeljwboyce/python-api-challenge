# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %% [markdown]
# ## Perform API Calls

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key 

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saskylakh
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 1 | oporapa
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | tommot
# Processing Record 8 of Set 1 | peniche
# Processing Record 9 of Set 1 | northam
# Processing Record 10 of Set 1 | praia da vitoria
# Processing Record 11 of Set 1 | bethel
# Processing Record 12 of Set 1 | pevek
# Processing Record 13 of Set 1 | airai
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | san cristobal
# Processing Record 16 of Set 1 | barabinsk
# Processing Record 17 of Set 1 | najran
# Processing Record 18 of Set 1 | progreso
# Processing Record 19 of Set 1 | pakhtakoron
# Processing Record 20 of Set 1 | leningradskiy
# Processing Record 21 of Set 1 | saint george
# Processing Record 22 of Set 1 | mandera
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | east london
# Processing Record 26 of Set 1 | hilo
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | torbay
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | sakaiminato
# Processing Record 31 of Set 1 | longyearbyen
# Processing Record 32 of Set 1 | acapulco
# Processing Record 33 of Set 1 | butaritari
# Processing Record 34 of Set 1 | ramshir
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | saint-augustin
# Processing Record 37 of Set 1 | chokurdakh
# Processing Record 38 of Set 1 | castro
# Processing Record 39 of Set 1 | fortuna
# Processing Record 40 of Set 1 | ribeira grande
# Processing Record 41 of Set 1 | vila franca do campo
# Processing Record 42 of Set 1 | hatta
# Processing Record 43 of Set 1 | norfolk
# Processing Record 44 of Set 1 | san quintin
# Processing Record 45 of Set 1 | ulaanbaatar
# Processing Record 46 of Set 1 | asau
# Processing Record 47 of Set 1 | upernavik
# Processing Record 48 of Set 1 | cidreira
# Processing Record 49 of Set 1 | thinadhoo
# Processing Record 50 of Set 1 | zhanaozen
# Processing Record 0 of Set 2 | port lincoln
# Processing Record 1 of Set 2 | jamestown
# Processing Record 2 of Set 2 | ankang
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | portland
# Processing Record 5 of Set 2 | mbeya
# Processing Record 6 of Set 2 | cochrane
# Processing Record 7 of Set 2 | lapeer
# Processing Record 8 of Set 2 | saint-philippe
# Processing Record 9 of Set 2 | atar
# Processing Record 10 of Set 2 | wajir
# Processing Record 11 of Set 2 | isangel
# Processing Record 12 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 2 | khatanga
# Processing Record 14 of Set 2 | mersing
# Processing Record 15 of Set 2 | opuwo
# Processing Record 16 of Set 2 | doha
# Processing Record 17 of Set 2 | luderitz
# Processing Record 18 of Set 2 | vardo
# Processing Record 19 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 2 | tiarei
# Processing Record 21 of Set 2 | taunsa
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | labuhan
# Processing Record 24 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 2 | provideniya
# Processing Record 26 of Set 2 | bredasdorp
# Processing Record 27 of Set 2 | henties bay
# Processing Record 28 of Set 2 | bollnas
# Processing Record 29 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 2 | hermanus
# Processing Record 31 of Set 2 | new norfolk
# Processing Record 32 of Set 2 | faya
# Processing Record 33 of Set 2 | sao filipe
# Processing Record 34 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 2 | atbasar
# Processing Record 36 of Set 2 | kalmunai
# Processing Record 37 of Set 2 | kruisfontein
# Processing Record 38 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 2 | tawkar
# City not found. Skipping...
# Processing Record 40 of Set 2 | bluff
# Processing Record 41 of Set 2 | dikson
# Processing Record 42 of Set 2 | punta arenas
# Processing Record 43 of Set 2 | klaksvik
# Processing Record 44 of Set 2 | waddan
# Processing Record 45 of Set 2 | komsomolskiy
# Processing Record 46 of Set 2 | arraial do cabo
# Processing Record 47 of Set 2 | avarua
# Processing Record 48 of Set 2 | celestun
# Processing Record 49 of Set 2 | morros
# Processing Record 0 of Set 3 | norman wells
# Processing Record 1 of Set 3 | elixir
# Processing Record 2 of Set 3 | lasa
# Processing Record 3 of Set 3 | asmara
# Processing Record 4 of Set 3 | alice springs
# Processing Record 5 of Set 3 | kapaa
# Processing Record 6 of Set 3 | lompoc
# Processing Record 7 of Set 3 | kybartai
# Processing Record 8 of Set 3 | kamenka
# Processing Record 9 of Set 3 | sao gabriel da cachoeira
# Processing Record 10 of Set 3 | busselton
# Processing Record 11 of Set 3 | menomonie
# Processing Record 12 of Set 3 | veraval
# Processing Record 13 of Set 3 | adrar
# Processing Record 14 of Set 3 | cayenne
# Processing Record 15 of Set 3 | caborca
# Processing Record 16 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 3 | hualmay
# Processing Record 18 of Set 3 | avera
# Processing Record 19 of Set 3 | talnakh
# Processing Record 20 of Set 3 | abu kamal
# Processing Record 21 of Set 3 | jand
# Processing Record 22 of Set 3 | victor harbor
# Processing Record 23 of Set 3 | altagracia de orituco
# Processing Record 24 of Set 3 | miraflores
# Processing Record 25 of Set 3 | gat
# Processing Record 26 of Set 3 | marovoay
# Processing Record 27 of Set 3 | ancud
# Processing Record 28 of Set 3 | ahuimanu
# Processing Record 29 of Set 3 | tuktoyaktuk
# Processing Record 30 of Set 3 | qaanaaq
# Processing Record 31 of Set 3 | vallenar
# Processing Record 32 of Set 3 | acajutla
# Processing Record 33 of Set 3 | hithadhoo
# Processing Record 34 of Set 3 | wahiawa
# Processing Record 35 of Set 3 | carnarvon
# Processing Record 36 of Set 3 | los llanos de aridane
# Processing Record 37 of Set 3 | high level
# Processing Record 38 of Set 3 | yellowknife
# Processing Record 39 of Set 3 | buraydah
# Processing Record 40 of Set 3 | fernley
# Processing Record 41 of Set 3 | souillac
# Processing Record 42 of Set 3 | sam chuk
# Processing Record 43 of Set 3 | novomalorossiyskaya
# Processing Record 44 of Set 3 | karasburg
# Processing Record 45 of Set 3 | dok kham tai
# Processing Record 46 of Set 3 | abha
# Processing Record 47 of Set 3 | jacqueville
# Processing Record 48 of Set 3 | andra
# Processing Record 49 of Set 3 | esperance
# Processing Record 0 of Set 4 | rafraf
# Processing Record 1 of Set 4 | kavaratti
# Processing Record 2 of Set 4 | pangnirtung
# Processing Record 3 of Set 4 | tasiilaq
# Processing Record 4 of Set 4 | murdochville
# Processing Record 5 of Set 4 | aswan
# Processing Record 6 of Set 4 | kamennomostskiy
# Processing Record 7 of Set 4 | trinidad
# Processing Record 8 of Set 4 | bitkine
# Processing Record 9 of Set 4 | georgetown
# Processing Record 10 of Set 4 | vostok
# Processing Record 11 of Set 4 | olafsvik
# Processing Record 12 of Set 4 | hasaki
# Processing Record 13 of Set 4 | mopipi
# Processing Record 14 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 4 | siirt
# Processing Record 16 of Set 4 | kaitangata
# Processing Record 17 of Set 4 | puerto ayora
# Processing Record 18 of Set 4 | megion
# Processing Record 19 of Set 4 | viedma
# Processing Record 20 of Set 4 | changqing
# Processing Record 21 of Set 4 | bengkulu
# Processing Record 22 of Set 4 | geraldton
# Processing Record 23 of Set 4 | coquimbo
# Processing Record 24 of Set 4 | cabo san lucas
# Processing Record 25 of Set 4 | mount gambier
# Processing Record 26 of Set 4 | deputatskiy
# Processing Record 27 of Set 4 | primorsk
# Processing Record 28 of Set 4 | karratha
# Processing Record 29 of Set 4 | nenjiang
# Processing Record 30 of Set 4 | laguna
# Processing Record 31 of Set 4 | bonavista
# Processing Record 32 of Set 4 | saldanha
# Processing Record 33 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 4 | barrow
# Processing Record 35 of Set 4 | chingirlau
# Processing Record 36 of Set 4 | mancio lima
# Processing Record 37 of Set 4 | pajusti
# Processing Record 38 of Set 4 | woodward
# Processing Record 39 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 40 of Set 4 | mandurah
# Processing Record 41 of Set 4 | hamilton
# Processing Record 42 of Set 4 | tiksi
# Processing Record 43 of Set 4 | kincardine
# Processing Record 44 of Set 4 | necochea
# Processing Record 45 of Set 4 | touros
# Processing Record 46 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 48 of Set 4 | zhanakorgan
# Processing Record 49 of Set 4 | aksha
# Processing Record 0 of Set 5 | denau
# City not found. Skipping...
# Processing Record 1 of Set 5 | constitucion
# Processing Record 2 of Set 5 | killarney
# Processing Record 3 of Set 5 | vaitape
# Processing Record 4 of Set 5 | caucaia
# Processing Record 5 of Set 5 | kimbe
# Processing Record 6 of Set 5 | te anau
# Processing Record 7 of Set 5 | brezova pod bradlom
# Processing Record 8 of Set 5 | bulgan
# Processing Record 9 of Set 5 | nanortalik
# Processing Record 10 of Set 5 | avesta
# Processing Record 11 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 12 of Set 5 | sinnamary
# Processing Record 13 of Set 5 | guadalupe y calvo
# Processing Record 14 of Set 5 | champerico
# Processing Record 15 of Set 5 | thompson
# Processing Record 16 of Set 5 | mezen
# Processing Record 17 of Set 5 | bayshore gardens
# Processing Record 18 of Set 5 | aginskoye
# Processing Record 19 of Set 5 | padang
# Processing Record 20 of Set 5 | mar del plata
# Processing Record 21 of Set 5 | lagoa
# Processing Record 22 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 5 | lorengau
# Processing Record 24 of Set 5 | bela
# Processing Record 25 of Set 5 | bilma
# Processing Record 26 of Set 5 | codrington
# Processing Record 27 of Set 5 | kristiansund
# Processing Record 28 of Set 5 | rawson
# Processing Record 29 of Set 5 | ucluelet
# Processing Record 30 of Set 5 | ambon
# Processing Record 31 of Set 5 | santiago del estero
# Processing Record 32 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 5 | pangai
# Processing Record 34 of Set 5 | kroonstad
# Processing Record 35 of Set 5 | golden
# Processing Record 36 of Set 5 | melfi
# Processing Record 37 of Set 5 | bambous virieux
# Processing Record 38 of Set 5 | husavik
# Processing Record 39 of Set 5 | burla
# Processing Record 40 of Set 5 | dagana
# Processing Record 41 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 42 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 5 | merritt island
# Processing Record 44 of Set 5 | okhotsk
# Processing Record 45 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 5 | aryanah
# Processing Record 47 of Set 5 | keffi
# Processing Record 48 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 49 of Set 5 | ponta do sol
# Processing Record 0 of Set 6 | salalah
# Processing Record 1 of Set 6 | nizhneangarsk
# Processing Record 2 of Set 6 | naryan-mar
# Processing Record 3 of Set 6 | orange park
# Processing Record 4 of Set 6 | ignacio zaragoza
# Processing Record 5 of Set 6 | vestmannaeyjar
# Processing Record 6 of Set 6 | lebu
# Processing Record 7 of Set 6 | tsiroanomandidy
# Processing Record 8 of Set 6 | kuhdasht
# Processing Record 9 of Set 6 | belyy yar
# Processing Record 10 of Set 6 | tagusao
# Processing Record 11 of Set 6 | coahuayana
# Processing Record 12 of Set 6 | maryville
# Processing Record 13 of Set 6 | bosaso
# Processing Record 14 of Set 6 | terrace
# Processing Record 15 of Set 6 | tiznit
# Processing Record 16 of Set 6 | riyadh
# Processing Record 17 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 6 | carballo
# Processing Record 19 of Set 6 | honningsvag
# Processing Record 20 of Set 6 | bambanglipuro
# Processing Record 21 of Set 6 | papara
# Processing Record 22 of Set 6 | sitka
# Processing Record 23 of Set 6 | san patricio
# Processing Record 24 of Set 6 | tomatlan
# Processing Record 25 of Set 6 | namibe
# Processing Record 26 of Set 6 | talara
# Processing Record 27 of Set 6 | port elizabeth
# Processing Record 28 of Set 6 | corinto
# Processing Record 29 of Set 6 | tiruvottiyur
# City not found. Skipping...
# Processing Record 30 of Set 6 | almaznyy
# Processing Record 31 of Set 6 | awbari
# Processing Record 32 of Set 6 | placido de castro
# Processing Record 33 of Set 6 | okoneshnikovo
# Processing Record 34 of Set 6 | manama
# Processing Record 35 of Set 6 | dalinghe
# City not found. Skipping...
# Processing Record 36 of Set 6 | honiara
# Processing Record 37 of Set 6 | katsuura
# Processing Record 38 of Set 6 | darbhanga
# Processing Record 39 of Set 6 | cordele
# Processing Record 40 of Set 6 | havelock
# Processing Record 41 of Set 6 | mahebourg
# Processing Record 42 of Set 6 | bathsheba
# Processing Record 43 of Set 6 | ilulissat
# Processing Record 44 of Set 6 | kodiak
# Processing Record 45 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 46 of Set 6 | pisco
# Processing Record 47 of Set 6 | kieta
# Processing Record 48 of Set 6 | chuy
# Processing Record 49 of Set 6 | moranbah
# Processing Record 0 of Set 7 | lashio
# Processing Record 1 of Set 7 | novaya zaimka
# Processing Record 2 of Set 7 | bowen
# Processing Record 3 of Set 7 | taltal
# Processing Record 4 of Set 7 | narsaq
# Processing Record 5 of Set 7 | bikin
# Processing Record 6 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 7 | tarakan
# Processing Record 8 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 9 of Set 7 | shingu
# Processing Record 10 of Set 7 | duvan
# Processing Record 11 of Set 7 | severo-kurilsk
# Processing Record 12 of Set 7 | yulara
# Processing Record 13 of Set 7 | kandrian
# Processing Record 14 of Set 7 | ahipara
# Processing Record 15 of Set 7 | pathalgaon
# Processing Record 16 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 7 | koshurnikovo
# Processing Record 18 of Set 7 | okandja
# City not found. Skipping...
# Processing Record 19 of Set 7 | huarmey
# Processing Record 20 of Set 7 | khani
# Processing Record 21 of Set 7 | evensk
# Processing Record 22 of Set 7 | linxia
# Processing Record 23 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 24 of Set 7 | seoul
# Processing Record 25 of Set 7 | aras
# Processing Record 26 of Set 7 | simao
# Processing Record 27 of Set 7 | deniliquin
# Processing Record 28 of Set 7 | jasper
# Processing Record 29 of Set 7 | ostrovnoy
# Processing Record 30 of Set 7 | morro bay
# Processing Record 31 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 7 | zuwarah
# Processing Record 33 of Set 7 | mastic beach
# Processing Record 34 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 35 of Set 7 | flin flon
# Processing Record 36 of Set 7 | kungurtug
# Processing Record 37 of Set 7 | puerto baquerizo moreno
# Processing Record 38 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 7 | aguimes
# Processing Record 40 of Set 7 | dingle
# Processing Record 41 of Set 7 | hami
# Processing Record 42 of Set 7 | senno
# Processing Record 43 of Set 7 | nizwa
# Processing Record 44 of Set 7 | joshimath
# Processing Record 45 of Set 7 | shitanjing
# Processing Record 46 of Set 7 | meulaboh
# Processing Record 47 of Set 7 | mahibadhoo
# Processing Record 48 of Set 7 | cleburne
# Processing Record 49 of Set 7 | saint-georges
# Processing Record 0 of Set 8 | uchiza
# Processing Record 1 of Set 8 | plettenberg bay
# Processing Record 2 of Set 8 | svetlaya
# Processing Record 3 of Set 8 | abu samrah
# Processing Record 4 of Set 8 | rhyl
# Processing Record 5 of Set 8 | zhigansk
# Processing Record 6 of Set 8 | vila velha
# Processing Record 7 of Set 8 | ericeira
# Processing Record 8 of Set 8 | buala
# Processing Record 9 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 10 of Set 8 | bandarbeyla
# Processing Record 11 of Set 8 | aktau
# Processing Record 12 of Set 8 | hay river
# Processing Record 13 of Set 8 | mount isa
# Processing Record 14 of Set 8 | bairiki
# Processing Record 15 of Set 8 | jackson
# Processing Record 16 of Set 8 | mangaratiba
# Processing Record 17 of Set 8 | kuybyshevskiy zaton
# Processing Record 18 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 19 of Set 8 | riberalta
# Processing Record 20 of Set 8 | fallon
# Processing Record 21 of Set 8 | mugumu
# Processing Record 22 of Set 8 | saint-hubert
# Processing Record 23 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 8 | yinchuan
# Processing Record 25 of Set 8 | djougou
# Processing Record 26 of Set 8 | tuatapere
# Processing Record 27 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 28 of Set 8 | lushunkou
# City not found. Skipping...
# Processing Record 29 of Set 8 | camana
# Processing Record 30 of Set 8 | san francisco
# Processing Record 31 of Set 8 | callaguip
# Processing Record 32 of Set 8 | grindavik
# Processing Record 33 of Set 8 | barra do garcas
# Processing Record 34 of Set 8 | mikhaylovskoye
# Processing Record 35 of Set 8 | ca mau
# Processing Record 36 of Set 8 | xifeng
# Processing Record 37 of Set 8 | tateyama
# Processing Record 38 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 39 of Set 8 | durusu
# Processing Record 40 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 41 of Set 8 | ust-kuyga
# Processing Record 42 of Set 8 | maturin
# Processing Record 43 of Set 8 | prince rupert
# Processing Record 44 of Set 8 | pichayevo
# Processing Record 45 of Set 8 | lufilufi
# Processing Record 46 of Set 8 | reyes
# Processing Record 47 of Set 8 | alta floresta
# Processing Record 48 of Set 8 | fatehgarh
# Processing Record 49 of Set 8 | synya
# Processing Record 0 of Set 9 | franklin
# Processing Record 1 of Set 9 | iqaluit
# Processing Record 2 of Set 9 | raga
# Processing Record 3 of Set 9 | kloulklubed
# Processing Record 4 of Set 9 | lensk
# Processing Record 5 of Set 9 | mnogovershinnyy
# Processing Record 6 of Set 9 | mossendjo
# Processing Record 7 of Set 9 | fengzhen
# Processing Record 8 of Set 9 | dunda
# Processing Record 9 of Set 9 | rey bouba
# Processing Record 10 of Set 9 | zachary
# Processing Record 11 of Set 9 | hwange
# Processing Record 12 of Set 9 | pare
# Processing Record 13 of Set 9 | fremont
# Processing Record 14 of Set 9 | dabakala
# Processing Record 15 of Set 9 | kusti
# Processing Record 16 of Set 9 | kodinar
# Processing Record 17 of Set 9 | nang rong
# Processing Record 18 of Set 9 | adjumani
# Processing Record 19 of Set 9 | ballina
# Processing Record 20 of Set 9 | galle
# Processing Record 21 of Set 9 | khash
# Processing Record 22 of Set 9 | mae sot
# Processing Record 23 of Set 9 | simimbaan
# Processing Record 24 of Set 9 | batouri
# Processing Record 25 of Set 9 | vilyuysk
# Processing Record 26 of Set 9 | parana
# Processing Record 27 of Set 9 | namwala
# Processing Record 28 of Set 9 | cap-aux-meules
# Processing Record 29 of Set 9 | la palma
# Processing Record 30 of Set 9 | bilibino
# Processing Record 31 of Set 9 | ottumwa
# Processing Record 32 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 9 | tashla
# Processing Record 34 of Set 9 | kokopo
# Processing Record 35 of Set 9 | pacific grove
# Processing Record 36 of Set 9 | hurricane
# Processing Record 37 of Set 9 | shaowu
# Processing Record 38 of Set 9 | newport
# Processing Record 39 of Set 9 | kahului
# Processing Record 40 of Set 9 | burns lake
# Processing Record 41 of Set 9 | nikolskoye
# Processing Record 42 of Set 9 | cherskiy
# Processing Record 43 of Set 9 | harper
# Processing Record 44 of Set 9 | pando
# Processing Record 45 of Set 9 | mogadishu
# Processing Record 46 of Set 9 | ashtabula
# Processing Record 47 of Set 9 | saint anthony
# Processing Record 48 of Set 9 | kazachinskoye
# Processing Record 49 of Set 9 | pangody
# Processing Record 0 of Set 10 | haines junction
# Processing Record 1 of Set 10 | woodbury
# Processing Record 2 of Set 10 | navashino
# Processing Record 3 of Set 10 | phan thiet
# Processing Record 4 of Set 10 | qui nhon
# Processing Record 5 of Set 10 | aranda de duero
# Processing Record 6 of Set 10 | voznesenye
# Processing Record 7 of Set 10 | birjand
# Processing Record 8 of Set 10 | olinda
# Processing Record 9 of Set 10 | kamaishi
# Processing Record 10 of Set 10 | sisimiut
# Processing Record 11 of Set 10 | taoudenni
# Processing Record 12 of Set 10 | kununurra
# Processing Record 13 of Set 10 | grand gaube
# Processing Record 14 of Set 10 | walla walla
# Processing Record 15 of Set 10 | jumla
# Processing Record 16 of Set 10 | karacakoy
# Processing Record 17 of Set 10 | kushima
# Processing Record 18 of Set 10 | okha
# Processing Record 19 of Set 10 | nabire
# Processing Record 20 of Set 10 | sisian
# Processing Record 21 of Set 10 | coihaique
# Processing Record 22 of Set 10 | faanui
# Processing Record 23 of Set 10 | xuddur
# Processing Record 24 of Set 10 | roma
# Processing Record 25 of Set 10 | kanigoro
# Processing Record 26 of Set 10 | nizhniy tsasuchey
# Processing Record 27 of Set 10 | troitsk
# Processing Record 28 of Set 10 | gualaceo
# Processing Record 29 of Set 10 | villazon
# Processing Record 30 of Set 10 | kargasok
# Processing Record 31 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 10 | lagunas
# Processing Record 33 of Set 10 | aksu
# Processing Record 34 of Set 10 | santa cruz
# Processing Record 35 of Set 10 | atasu
# Processing Record 36 of Set 10 | cao bang
# Processing Record 37 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 38 of Set 10 | astana
# Processing Record 39 of Set 10 | seydi
# Processing Record 40 of Set 10 | ghatanji
# Processing Record 41 of Set 10 | casambalangan
# Processing Record 42 of Set 10 | fenelon falls
# Processing Record 43 of Set 10 | itarema
# Processing Record 44 of Set 10 | dunedin
# Processing Record 45 of Set 10 | ritchie
# Processing Record 46 of Set 10 | invercargill
# Processing Record 47 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 10 | zarate
# Processing Record 0 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 11 | angra dos reis
# Processing Record 2 of Set 11 | binzhou
# Processing Record 3 of Set 11 | moroni
# Processing Record 4 of Set 11 | majene
# Processing Record 5 of Set 11 | igrim
# Processing Record 6 of Set 11 | makakilo city
# Processing Record 7 of Set 11 | sola
# Processing Record 8 of Set 11 | ust-kulom
# Processing Record 9 of Set 11 | tigil
# Processing Record 10 of Set 11 | the valley
# Processing Record 11 of Set 11 | crotone
# Processing Record 12 of Set 11 | saint-leu
# Processing Record 13 of Set 11 | kudahuvadhoo
# Processing Record 14 of Set 11 | biak
# Processing Record 15 of Set 11 | zyryanka
# Processing Record 16 of Set 11 | steamboat springs
# Processing Record 17 of Set 11 | liverpool
# Processing Record 18 of Set 11 | tadine
# Processing Record 19 of Set 11 | areka
# Processing Record 20 of Set 11 | bhawanipatna
# Processing Record 21 of Set 11 | goroka
# Processing Record 22 of Set 11 | dapdap
# Processing Record 23 of Set 11 | tura
# Processing Record 24 of Set 11 | clyde river
# Processing Record 25 of Set 11 | la cumbre
# Processing Record 26 of Set 11 | maloshuyka
# City not found. Skipping...
# Processing Record 27 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 28 of Set 11 | nome
# Processing Record 29 of Set 11 | atambua
# Processing Record 30 of Set 11 | mezhgorye
# Processing Record 31 of Set 11 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 11 | nouadhibou
# Processing Record 33 of Set 11 | kosh-agach
# Processing Record 34 of Set 11 | elizabeth city
# Processing Record 35 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 11 | matanzas
# Processing Record 37 of Set 11 | berlevag
# Processing Record 38 of Set 11 | grunberg
# Processing Record 39 of Set 11 | phibun mangsahan
# Processing Record 40 of Set 11 | rocha
# Processing Record 41 of Set 11 | sorland
# Processing Record 42 of Set 11 | strand
# Processing Record 43 of Set 11 | gigmoto
# Processing Record 44 of Set 11 | jiuquan
# Processing Record 45 of Set 11 | tuy hoa
# Processing Record 46 of Set 11 | umm lajj
# Processing Record 47 of Set 11 | annau
# Processing Record 48 of Set 11 | port hedland
# Processing Record 49 of Set 11 | novopokrovka
# Processing Record 0 of Set 12 | guerrero negro
# Processing Record 1 of Set 12 | mildura
# Processing Record 2 of Set 12 | chapleau
# Processing Record 3 of Set 12 | malatya
# Processing Record 4 of Set 12 | yerofey pavlovich
# Processing Record 5 of Set 12 | zhaoyang
# Processing Record 6 of Set 12 | jiwani
# Processing Record 7 of Set 12 | san policarpo
# Processing Record 8 of Set 12 | kumphawapi
# Processing Record 9 of Set 12 | ambanja
# Processing Record 10 of Set 12 | derzhavinsk
# Processing Record 11 of Set 12 | victoria
# Processing Record 12 of Set 12 | kutum
# Processing Record 13 of Set 12 | hindaun
# Processing Record 14 of Set 12 | angola
# Processing Record 15 of Set 12 | pafos
# Processing Record 16 of Set 12 | iracoubo
# Processing Record 17 of Set 12 | beloha
# Processing Record 18 of Set 12 | goundam
# Processing Record 19 of Set 12 | sistranda
# Processing Record 20 of Set 12 | karonga
# Processing Record 21 of Set 12 | naze
# Processing Record 22 of Set 12 | amahai
# Processing Record 23 of Set 12 | namatanai
# Processing Record 24 of Set 12 | broome
# Processing Record 25 of Set 12 | lima
# Processing Record 26 of Set 12 | santa maria
# Processing Record 27 of Set 12 | mezhdurechenskiy
# Processing Record 28 of Set 12 | yarim
# Processing Record 29 of Set 12 | bronzani majdan
# Processing Record 30 of Set 12 | tomigusuku
# Processing Record 31 of Set 12 | chalus
# Processing Record 32 of Set 12 | makung
# City not found. Skipping...
# Processing Record 33 of Set 12 | saint-pierre
# Processing Record 34 of Set 12 | zirovnice
# Processing Record 35 of Set 12 | rincon viejo
# Processing Record 36 of Set 12 | lixourion
# Processing Record 37 of Set 12 | phrai bung
# City not found. Skipping...
# Processing Record 38 of Set 12 | dryden
# Processing Record 39 of Set 12 | maragogi
# Processing Record 40 of Set 12 | jutai
# Processing Record 41 of Set 12 | ouango
# Processing Record 42 of Set 12 | ivaipora
# Processing Record 43 of Set 12 | lavrentiya
# Processing Record 44 of Set 12 | caceres
# Processing Record 45 of Set 12 | roald
# Processing Record 46 of Set 12 | chabahar
# Processing Record 47 of Set 12 | gulariya
# Processing Record 48 of Set 12 | tungkang
# City not found. Skipping...
# Processing Record 49 of Set 12 | puqi
# Processing Record 0 of Set 13 | minden
# Processing Record 1 of Set 13 | forestville
# Processing Record 2 of Set 13 | palmer
# Processing Record 3 of Set 13 | vredendal
# Processing Record 4 of Set 13 | krasnaya zarya
# Processing Record 5 of Set 13 | chase
# Processing Record 6 of Set 13 | jinchang
# Processing Record 7 of Set 13 | karagay
# Processing Record 8 of Set 13 | dubai
# Processing Record 9 of Set 13 | pathein
# Processing Record 10 of Set 13 | turiacu
# Processing Record 11 of Set 13 | vestmanna
# Processing Record 12 of Set 13 | valente
# Processing Record 13 of Set 13 | jalu
# Processing Record 14 of Set 13 | svetlogorsk
# Processing Record 15 of Set 13 | beringovskiy
# Processing Record 16 of Set 13 | nogliki
# Processing Record 17 of Set 13 | pouebo
# Processing Record 18 of Set 13 | gobabis
# Processing Record 19 of Set 13 | malakal
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Extract relevant fields from the data frame
lats = city_data_pd["Lat"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]

# Export the City_Data into a csv
city_data_pd.to_csv(output_data_file, index_label="City_ID")

# Show Record Count
city_data_pd.count()
# Out:
# City          565
# Lat           565
# Lng           565
# Max Temp      565
# Humidity      565
# Cloudiness    565
# Wind Speed    565
# Country       565
# Date          565
# dtype: int64

# %%
# Display the City Data Frame
city_data_pd.head()
# Out:
#         City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  saskylakh  71.92  114.08     -6.30        98         100        0.07
# 1  cape town -33.93   18.42     69.01        93          75       13.87
# 2    oporapa   2.05  -75.98     71.33        79          84        2.55
# 3    rikitea -23.12 -134.97     78.12        78          95       19.10
# 4     tommot  58.96  126.29      2.48        97         100        1.97
#
#   Country        Date
# 0      RU  1581196318
# 1      ZA  1581196130
# 2      CO  1581196318
# 3      PF  1581196318
# 4      RU  1581196318

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lats, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Run regresson on southern hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] >= 0)]
southern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] < 0)]

# %% [markdown]
# ###  Max Temp vs. Latitude Linear Regression

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp',(6,30))
# Out:
# The r-squared is: -0.8529438959012092

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp', (-30,40))
# Out:
# The r-squared is: 0.5276579458738865

# %% [markdown]
# The high r value indicates a strong positive correlation between latitude and max temperature.

# %% [markdown]
# ### Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity',(40,10))
# Out:
# The r-squared is: 0.40629663130463606

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity', (-30,150))
# Out:
# The r-squared is: 0.24251997239303127

# %% [markdown]
# The low r values indicate a weak to no relationship between humidity and latitude.

# %% [markdown]
# ### Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (40,10))
# Out:
# The r-squared is: 0.1490936150757247

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (-30,30))
# Out:
# The r-squared is: 0.31332752882864334

# %% [markdown]
# The low r values indicate a weak positive relationship between latitude and cloudiness.

# %% [markdown]
# ### Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (40,25))
# Out:
# The r-squared is: 0.02064730864616587

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (-30,30))
# Out:
# The r-squared is: -0.10063504520578062

# %% [markdown]
# The low r values indicate that there is no real relationship between wind speed and latitude." The difference between the hemispheres doesn't seem to be significant enough to comment upon.
